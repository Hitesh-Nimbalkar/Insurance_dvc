# %%
import pandas as pd
import os
import dill

# %%
def load_object(file_path: str ) -> object:

        if not os.path.exists(file_path):
            raise Exception(f"The file: {file_path} is not exists")
        with open(file_path, "rb") as file_obj:
            return dill.load(file_obj)

# %%
model_path=r"E:\Projects\Deployment\New INurance\Insurance_dvc\Saved_model\model.pkl"

# %%
model = load_object(file_path=model_path)
# Out:
# [13:41:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.

# %% [markdown]
# ## Create Bento

# %%
import bentoml
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import bentoml
#
# File c:\Users\Hitesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\bentoml\__init__.py:25
#      22 from ._internal.configuration import set_serialization_strategy
#      24 # Inject dependencies and configurations
# ---> 25 load_config()
#      27 # BentoML built-in types
#      28 from ._internal.bento import Bento
#
# File c:\Users\Hitesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\bentoml\_internal\configuration\__init__.py:131, in load_config(bentoml_config_file)
#     128 def load_config(bentoml_config_file: str | None = None):
#     129     """Load global configuration of BentoML"""
# --> 131     from .containers import BentoMLConfiguration
#     132     from .containers import BentoMLContainer
#     134     if not bentoml_config_file:
#
# ...

# %%
model = load_object(model_path)
bento_model = bentoml.sklearn.save_model("sklearn_model", model)
print(f"Bento model tag = {bento_model.tag}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 model = load_object(model_path)
# ----> 2 bento_model = bentoml.sklearn.save_model("sklearn_model", model)
#       3 print(f"Bento model tag = {bento_model.tag}")
#
# NameError: name 'bentoml' is not defined

# %%
load_model_and_save_it_to_bento(model_path=model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 load_model_and_save_it_to_bento(model_path=model_path)
#
# NameError: name 'load_model_and_save_it_to_bento' is not defined
